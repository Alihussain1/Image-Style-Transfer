# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
img = cv2.imread('image_06734.jpg',1)
normalized_img = np.zeros(img.shape).astype(float)
print(type(normalized_img[0][0][0]))
normalized_img = cv2.normalize(img.astype(float),normalized_img,0,1,cv2.NORM_MINMAX)
print(type(normalized_img[0][0][0]))
normalized_img.astype(float)
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# array([[[0.08235294, 0.21176471, 0.        ],
#         [0.08627451, 0.20392157, 0.        ],
#         [0.09803922, 0.2       , 0.01960784],
#         ...,
#         [0.23921569, 0.27058824, 0.24313725],
#         [0.23529412, 0.26666667, 0.23921569],
#         [0.22745098, 0.25882353, 0.23137255]],
#
#        [[0.08627451, 0.21568627, 0.        ],
#         [0.08627451, 0.20392157, 0.        ],
#         [0.10980392, 0.2       , 0.02352941],
#         ...,
#         [0.22745098, 0.25882353, 0.23137255],
#         [0.22352941, 0.25490196, 0.22745098],
#         [0.21960784, 0.25098039, 0.22352941]],
#
#        [[0.09019608, 0.21176471, 0.        ],
#         [0.09411765, 0.20392157, 0.        ],
#         [0.10980392, 0.2       , 0.02352941],
#         ...,
#         [0.22352941, 0.25490196, 0.22745098],
#         [0.22352941, 0.25490196, 0.22745098],
#         [0.21960784, 0.25098039, 0.22352941]],
#
#        ...,
#
#        [[0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         ...,
#         [0.0627451 , 0.1254902 , 0.03137255],
#         [0.0627451 , 0.1254902 , 0.03137255],
#         [0.0627451 , 0.1254902 , 0.03137255]],
#
#        [[0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         ...,
#         [0.0627451 , 0.1254902 , 0.03137255],
#         [0.0627451 , 0.1254902 , 0.03137255],
#         [0.0627451 , 0.1254902 , 0.03137255]],
#
#        [[0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         [0.03137255, 0.07058824, 0.00784314],
#         ...,
#         [0.05882353, 0.12156863, 0.02745098],
#         [0.05882353, 0.12156863, 0.02745098],
#         [0.05882353, 0.12156863, 0.02745098]]])

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (500, 523, 3)

# %%
img_converted = np.zeros_like(img,dtype='float')
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        H = 0
        S = 0
        I = 0
        R = float(normalized_img[i][j][2])
        G = float(normalized_img[i][j][1])
        B = float(normalized_img[i][j][0])
        RGB_sum = R + G + B
        RGB_min = min(R, G, B)
        #print("{} ,{} ,{} , {} , {}".format(R,G,B,RGB_min,RGB_sum))
        I = (1/3) * RGB_sum
        if R == G and G == B:
            H = 0
            S = 0
        else:
            S = 1 - ((3*RGB_min)/RGB_sum)
            if S > 0.9999:
                S = 1
            if S < 0.00001:
                S = 0
                H = 0
            else:
                dividend = (1/2) * ((R-G) + (R-B))
                divisor = math.sqrt(math.pow((R-G),2) + (R-B)*(G-B))
                w = dividend/divisor
                if w > 1:
                    w=1
                elif w < -1:
                    w = -1                    
                H = math.acos(w)
                if B > G:
                    H = (2*math.pi) - H
        img_converted[i][j][0] = H * (180 / math.pi)
        img_converted[i][j][1] = S
        img_converted[i][j][2] = I

# %%
plt.imshow(img_converted)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("RGB {},{},{}  , HSI {},{},{}".format(normalized_img[0][0][2],normalized_img[0][0][1],normalized_img[0][0][0],img_converted[0][0][0]
                                           ,img_converted[0][0][1],img_converted[0][0][2]))
# Out:
# RGB 0.0,0.21176470588235294,0.08235294117647059  , HSI 142.6888893056155,1.0,0.09803921568627451

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(4,4,1)
plt.imshow(img_converted[0:,0:20])
ax = fig.add_subplot(4,4,2)
plt.imshow(img_converted[0:20,0:])
ax = fig.add_subplot(4,4,3)
plt.imshow(img_converted[0:,-20:-1])
ax = fig.add_subplot(4,4,4)
plt.imshow(img_converted[-20:-1,0:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
